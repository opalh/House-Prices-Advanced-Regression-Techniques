# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from __future__ import division

# %%
data=pd.read_csv('C:/Users/admin/train1.csv')

# %%
data.head(30)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
sorted(data.isna().sum())
# Out:
# [0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  1L,
#  8L,
#  8L,
#  37L,
#  37L,
#  37L,
#  38L,
#  38L,
#  81L,
#  81L,
#  81L,
#  81L,
#  81L,
#  259L,
#  690L,
#  1179L,
#  1369L,
#  1406L,
#  1453L]

# %%
#data.isna().sum().set_option('display.width', 1000)

# %%
X = data.drop(['SalePrice'], axis=1)
y = data['SalePrice'].as_matrix()
X=X.dropna(axis=1, how='any')
X=pd.get_dummies(X)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
print(X_train.shape, y_train.shape)
# Out:
# ((1095, 216), (1095L,))

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
SalePrice_predict= lr.predict(X_test)

# %%
lr.coef_
# Out:
# array([ 3.40253141e-01,  3.82625730e+01,  6.54824325e-01,  6.41202860e+03,
#         5.33219805e+03,  4.32887568e+02,  1.03876694e+02,  1.99549418e+01,
#         6.48252126e+00, -5.00204828e+00,  2.14354624e+01,  2.35824207e+01,
#         2.91952783e+01, -1.19847813e+01,  4.07932536e+01, -2.92940844e+02,
#        -2.51613615e+03,  1.68753086e+03, -2.87077370e+03, -6.61118696e+03,
#        -1.06718234e+04,  1.43463800e+03,  8.62343799e+02,  4.63273005e+03,
#         8.53879181e+00,  1.49291505e+01,  3.59704468e+01, -5.25358699e+00,
#         2.10542530e+01,  4.27895884e+01,  6.70851998e+01,  3.91879421e-01,
#        -3.21386899e+02,  2.66707306e+02, -3.27951007e+04,  6.37778808e+03,
#         4.82923400e+03,  1.17017332e+04,  9.88634538e+03, -1.25071346e+04,
#         1.25071346e+04, -1.26046855e+03,  2.25179747e+03,  5.00825458e+02,
#        -1.49215439e+03, -2.14507270e+03,  8.98452561e+03, -6.71894938e+03,
# ...

# %%
lr.intercept_
# Out:
# -1733638.383319434

# %%
SalePrice_predict.shape
# Out:
# (365L,)

# %%
from sklearn.metrics import mean_squared_log_error

def rmsle(real, predicted):
   sum=0.0
   for x in range(len(predicted)):
       if predicted[x]<0 or real[x]<0: #check for negative values
           continue
       p = np.log(predicted[x]+1)
       r = np.log(real[x]+1)
       sum = sum + (p - r)**2
   return (sum/len(predicted))**0.5
#mean_squared_log_error(y_test, new_pr)

rmsle(y_test, SalePrice_predict)
# Out:
# 0.1719739496825557

# %%
#########

# %%
# X=X.drop(['Alley','LotFrontage','FireplaceQu','PoolQC','Fence','MiscFeature','GarageType',
#       'GarageYrBlt', 'GarageFinish', 'GarageQual',
#       'GarageCond'],axis=1)

# %%
data.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %%
data.columns
# Out:
# Index([u'Id', u'MSSubClass', u'MSZoning', u'LotFrontage', u'LotArea',
#        u'Street', u'Alley', u'LotShape', u'LandContour', u'Utilities',
#        u'LotConfig', u'LandSlope', u'Neighborhood', u'Condition1',
#        u'Condition2', u'BldgType', u'HouseStyle', u'OverallQual',
#        u'OverallCond', u'YearBuilt', u'YearRemodAdd', u'RoofStyle',
#        u'RoofMatl', u'Exterior1st', u'Exterior2nd', u'MasVnrType',
#        u'MasVnrArea', u'ExterQual', u'ExterCond', u'Foundation', u'BsmtQual',
#        u'BsmtCond', u'BsmtExposure', u'BsmtFinType1', u'BsmtFinSF1',
#        u'BsmtFinType2', u'BsmtFinSF2', u'BsmtUnfSF', u'TotalBsmtSF',
#        u'Heating', u'HeatingQC', u'CentralAir', u'Electrical', u'1stFlrSF',
#        u'2ndFlrSF', u'LowQualFinSF', u'GrLivArea', u'BsmtFullBath',
#        u'BsmtHalfBath', u'FullBath', u'HalfBath', u'BedroomAbvGr',
#        u'KitchenAbvGr', u'KitchenQual', u'TotRmsAbvGrd', u'Functional',
# ...

# %%
plt.bar(x=pd.value_counts(data.SalePrice).keys(), height=pd.value_counts(data.LotArea),
        width=0.5)
plt.xticks(rotation='vertical')
plt.title('Car manufacturers')
plt.ylabel('Number of samples')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-41ec9f6e7b09> in <module>()
#       1 plt.bar(x=pd.value_counts(data.SalePrice).keys(), height=pd.value_counts(data.LotArea),
# ----> 2         width=0.5)
#       3 plt.xticks(rotation='vertical')
#       4 plt.title('Car manufacturers')
#       5 plt.ylabel('Number of samples')
#
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\pyplot.py in bar(*args, **kwargs)
#    2646                       mplDeprecation)
#    2647     try:
# -> 2648         ret = ax.bar(*args, **kwargs)
#    2649     finally:
#    2650         ax._hold = washold
#
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# ...

# %%
data[[u'GarageFinish', u'GarageCars', u'WoodDeckSF', u'OpenPorchSF']]
# Out:
#      GarageFinish  GarageCars  WoodDeckSF  OpenPorchSF
# 0             RFn           2           0           61
# 1             RFn           2         298            0
# 2             RFn           2           0           42
# 3             Unf           3           0           35
# 4             RFn           3         192           84
# 5             Unf           2          40           30
# 6             RFn           2         255           57
# 7             RFn           2         235          204
# 8             Unf           2          90            0
# 9             RFn           1           0            4
# 10            Unf           1           0            0
# 11            Fin           3         147           21
# 12            Unf           1         140            0
# 13            RFn           3         160           33
# 14            RFn           1           0          213
# 15            Unf           2          48          112
# ...

# %%
data.MiscFeature.unique()
# Out:
# array([nan, 'Shed', 'Gar2', 'Othr', 'TenC'], dtype=object)

# %%
data.MiscFeature.value_counts()
# Out:
# Shed    49
# Othr     2
# Gar2     2
# TenC     1
# Name: MiscFeature, dtype: int64

# %%
data.Neighborhood.unique()
# Out:
# array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object)

# %%
data.SaleCondition.value_counts()
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64

# %%
data.SaleType.unique()
# Out:
# array(['WD', 'New', 'COD', 'ConLD', 'ConLI', 'CWD', 'ConLw', 'Con', 'Oth'],
#       dtype=object)

# %%
data.SaleType.value_counts()
# Out:
# WD       1267
# New       122
# COD        43
# ConLD       9
# ConLw       5
# ConLI       5
# CWD         4
# Oth         3
# Con         2
# Name: SaleType, dtype: int64

# %%
data2=data.drop(['Id', 'MSSubClass', 'MSZoning', 'Street', 'LotFrontage', 'Alley', 'LandSlope', 'LotConfig',
             'Utilities', 'LandContour', 'Condition1', 'Condition2', 'RoofStyle', 'RoofMatl', 'BldgType',
             'MasVnrArea', 'ExterCond', 'ExterQual', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
             'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'Heating', 'HeatingQC', 'CentralAir',
             'Electrical', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'KitchenAbvGr',
             'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageArea',
             'GarageQual', 'GarageCond', 'PavedDrive', 'PoolArea', 'Fence', 'MoSold', 'SaleType', 'SaleCondition'], axis=1)

# %%
mapping={'Mr':0, 'Miss':1, 'Mrs':2,'Master':3,'Dr':0, 'Rev':0,'Mlle':2, 'Major':0, 'Col':0,'Countess':2, 'Lady':2,'Jonkheer':0, 'Ms':1,'Capt':0, 'Mme':2, 'Don':0,'Sir':0}

# %%
data2[[u'GarageFinish', u'GarageCars', u'WoodDeckSF', u'OpenPorchSF']]
# Out:
#      GarageFinish  GarageCars  WoodDeckSF  OpenPorchSF
# 0             RFn           2           0           61
# 1             RFn           2         298            0
# 2             RFn           2           0           42
# 3             Unf           3           0           35
# 4             RFn           3         192           84
# 5             Unf           2          40           30
# 6             RFn           2         255           57
# 7             RFn           2         235          204
# 8             Unf           2          90            0
# 9             RFn           1           0            4
# 10            Unf           1           0            0
# 11            Fin           3         147           21
# 12            Unf           1         140            0
# 13            RFn           3         160           33
# 14            RFn           1           0          213
# 15            Unf           2          48          112
# ...

# %%
data2.GarageFinish.unique()
# Out:
# array(['RFn', 'Unf', 'Fin', nan], dtype=object)

# %%
data2.GarageFinish.value_counts()
# Out:
# Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64

# %%
data2.GarageFinish.isna().sum()
# Out:
# 81

# %%
## if we have Garage 1, if not 0

# %%
mapping={'RFn':1, 'Unf':0, 'Fin':1}

# %%
data2.GarageFinish=data.GarageFinish.map(mapping)

# %%
data2.GarageFinish.fillna(0,inplace=True)

# %%
data2.GarageFinish.unique()
# Out:
# array([1., 0.])

# %%
data2.columns
# Out:
# Index([u'LotArea', u'LotShape', u'Neighborhood', u'HouseStyle', u'OverallQual',
#        u'OverallCond', u'YearBuilt', u'YearRemodAdd', u'Exterior1st',
#        u'Exterior2nd', u'MasVnrType', u'Foundation', u'TotalBsmtSF',
#        u'1stFlrSF', u'2ndFlrSF', u'BsmtHalfBath', u'FullBath', u'HalfBath',
#        u'BedroomAbvGr', u'Fireplaces', u'GarageFinish', u'GarageCars',
#        u'WoodDeckSF', u'OpenPorchSF', u'EnclosedPorch', u'3SsnPorch',
#        u'ScreenPorch', u'PoolQC', u'MiscFeature', u'MiscVal', u'YrSold',
#        u'SalePrice'],
#       dtype='object')

# %%
# if np.logical_or(data2.WoodDeckSF!=0, data2.OpenPorchSF!=0,data2.EnclosedPorch!=0,data2.3SsnPorch!=0,data2.ScreenPorch!=0):
#     data2.OpenPorchSF=1
# else:
#     data2.OpenPorchSF=0

# %%
##data.WoodDeckSF.notna()

# %%
data2.OpenPorchSF = data2.WoodDeckSF+ data2.OpenPorchSF+ data2.EnclosedPorch+ data2["3SsnPorch"]+data2.ScreenPorch

# %%
data2=data2.drop(['WoodDeckSF', 'EnclosedPorch', '3SsnPorch','ScreenPorch'], axis=1)

# %%
plt.scatter(data.SalePrice, data.MasVnrType)

# %%
data2.MasVnrType.unique()
# Out:
# array(['BrkFace', 'None', 'Stone', 'BrkCmn', nan], dtype=object)

# %%
data2.MasVnrType.value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
data2.MasVnrType.isna().sum()
# Out:
# 8

# %%
mapping={'BrkFace':1, 'None':0, 'Stone':2, 'BrkCmn':3}
data2.MasVnrType=data2.MasVnrType.map(mapping)

# %%
data2.MasVnrType.fillna(0,inplace=True)

# %%
data2.columns
# Out:
# Index([u'LotArea', u'LotShape', u'Neighborhood', u'HouseStyle', u'OverallQual',
#        u'OverallCond', u'YearBuilt', u'YearRemodAdd', u'Exterior1st',
#        u'Exterior2nd', u'MasVnrType', u'Foundation', u'TotalBsmtSF',
#        u'1stFlrSF', u'2ndFlrSF', u'BsmtHalfBath', u'FullBath', u'HalfBath',
#        u'BedroomAbvGr', u'Fireplaces', u'GarageFinish', u'GarageCars',
#        u'OpenPorchSF', u'PoolQC', u'MiscFeature', u'MiscVal', u'YrSold',
#        u'SalePrice'],
#       dtype='object')

# %%
mapping={'0':0, '1':1, '2':1,'3':1}
data2.Fireplaces=data2.Fireplaces.map(mapping)
data2=data2.drop(['Fireplaces'], axis=1)

# %%
data2.LotShape=data2.LotShape.map({'Reg':0, 'IR1':1, 'IR2':2, 'IR3':3})

data2.PoolQC =data2.PoolQC.map({'Gd':1, 'Fa':1, 'Ex':1})
data2['PoolQC'] = data2['PoolQC'].fillna(0)

# %%
data2.OpenPorchSF=(data2.OpenPorchSF > 1).astype(int)

# %%
data2=data2.drop([u'LotShape',u'Exterior1st',u'Neighborhood',
       u'Exterior2nd', u'MasVnrType', u'BsmtHalfBath', u'HalfBath', u'MiscFeature', u'Foundation'],axis=1)

# %%
data2.OpenPorchSF.value_counts()
# Out:
# 1    1206
# 0     254
# Name: OpenPorchSF, dtype: int64

# %%
data2.columns
# Out:
# Index([u'LotArea', u'HouseStyle', u'OverallQual', u'OverallCond', u'YearBuilt',
#        u'YearRemodAdd', u'TotalBsmtSF', u'1stFlrSF', u'2ndFlrSF', u'FullBath',
#        u'BedroomAbvGr', u'GarageFinish', u'GarageCars', u'OpenPorchSF',
#        u'PoolQC', u'MiscVal', u'YrSold', u'SalePrice'],
#       dtype='object')

# %%
data2
# Out:
#       LotArea HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0        8450     2Story            7            5       2003          2003
# 1        9600     1Story            6            8       1976          1976
# 2       11250     2Story            7            5       2001          2002
# 3        9550     2Story            7            5       1915          1970
# 4       14260     2Story            8            5       2000          2000
# 5       14115     1.5Fin            5            5       1993          1995
# 6       10084     1Story            8            5       2004          2005
# 7       10382     2Story            7            6       1973          1973
# 8        6120     1.5Fin            7            5       1931          1950
# 9        7420     1.5Unf            5            6       1939          1950
# 10      11200     1Story            5            5       1965          1965
# ...

# %%
data2=pd.get_dummies(data2)

# %%
data2
# Out:
#       LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  TotalBsmtSF  \
# 0        8450            7            5       2003          2003          856
# 1        9600            6            8       1976          1976         1262
# 2       11250            7            5       2001          2002          920
# 3        9550            7            5       1915          1970          756
# 4       14260            8            5       2000          2000         1145
# 5       14115            5            5       1993          1995          796
# 6       10084            8            5       2004          2005         1686
# 7       10382            7            6       1973          1973         1107
# 8        6120            7            5       1931          1950          952
# 9        7420            5            6       1939          1950          991
# 10      11200            5            5       1965          1965         1040
# ...

# %%
X = data2.drop(['SalePrice'], axis=1)
y = data2['SalePrice'].as_matrix()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
print(X_train.shape, y_train.shape)
# Out:
# ((1095, 24), (1095L,))

# %%
#data2.isna().sum()

# %%
data2.describe()
# Out:
#              LotArea  OverallQual  OverallCond    YearBuilt  YearRemodAdd  \
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean    10516.828082     6.099315     5.575342  1971.267808   1984.865753
# std      9981.264932     1.382997     1.112799    30.202904     20.645407
# min      1300.000000     1.000000     1.000000  1872.000000   1950.000000
# 25%      7553.500000     5.000000     5.000000  1954.000000   1967.000000
# 50%      9478.500000     6.000000     5.000000  1973.000000   1994.000000
# 75%     11601.500000     7.000000     6.000000  2000.000000   2004.000000
# max    215245.000000    10.000000     9.000000  2010.000000   2010.000000
#
#        TotalBsmtSF     1stFlrSF     2ndFlrSF     FullBath  BedroomAbvGr  \
# count  1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean   1057.429452  1162.626712   346.992466     1.565068      2.866438
# std     438.705324   386.587738   436.528436     0.550916      0.815778
# ...

# %%
###preprocessing

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()  # define scaler
scaler.fit(X_train)  # fit scaler ONLY on the training data

print('mean: {}\nstd:  {}'.format(scaler.mean_ , scaler.scale_))

# transform on both sets:
train_scaled = scaler.transform(X_train)
test_scaled = scaler.transform(X_test)
# Out:
# mean: [1.06773196e+04 6.10136986e+00 5.57534247e+00 1.97137260e+03
#  1.98497260e+03 1.05977717e+03 1.16404658e+03 3.37735160e+02
#  1.55159817e+00 2.84566210e+00 5.28767123e-01 1.77168950e+00
#  8.31963470e-01 4.56621005e-03 4.24511416e+01 2.00779817e+03
#  1.03196347e-01 9.13242009e-03 5.10502283e-01 5.47945205e-03
#  5.47945205e-03 2.99543379e-01 2.46575342e-02 4.20091324e-02]
# std:  [1.07477174e+04 1.38740188e+00 1.10272980e+00 3.02165696e+01
#  2.06610210e+01 4.45789237e+02 3.88032481e+02 4.34888841e+02
#  5.51324435e-01 8.14770548e-01 4.99171767e-01 7.38332302e-01
#  3.73898722e-01 6.74192834e-02 5.47169818e+02 1.32912453e+00
#  3.04215156e-01 9.51263318e-02 4.99889690e-01 7.38202388e-02
#  7.38202388e-02 4.58058013e-01 1.55079142e-01 2.00609983e-01]

# %%
# from sklearn.feature_selection import f_classif
# from sklearn.feature_selection import SelectPercentile

# selector = SelectPercentile(f_classif)
# selector.fit(X_train, y_train)
# X_train = selector.transform(X_train)
# X_test = selector.transform(X_test)

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
est = sm.OLS(y_train, X_train)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.769
# Method:                 Least Squares   F-statistic:                     159.7
# Date:                Sun, 29 Apr 2018   Prob (F-statistic):               0.00
# Time:                        14:29:14   Log-Likelihood:                -13115.
# No. Observations:                1095   AIC:                         2.628e+04
# Df Residuals:                    1071   BIC:                         2.640e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# LotArea               0.5647      0.118      4.787      0.000       0.333       0.796
# ...

# %%
plt.scatter(data.SalePrice, data.Neighborhood)

# %%
plt.scatter(data.SalePrice, data.MiscVal)

# %%
##############

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)

from sklearn.metrics import mean_squared_log_error
y_test = y_test.astype('float64')

def rmsle(real, predicted):
    sum=0.0
    for x in range(len(predicted)):
        if predicted[x]<0 or real[x]<0: #check for negative values
            continue
        p = np.log(predicted[x]+1)
        r = np.log(real[x]+1)
        sum = sum + (p - r)**2
    return (sum/len(predicted))**0.5

preds = lr.predict(X_test)
print('rmsle:', rmsle(y_test, preds))
# Out:
# ('rmsle:', 0.167019593450763)

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(max_depth=2)
reg.fit(X_train, y_train)
pred = reg.predict(X_test)

# %%
data2.describe()
# Out:
#              LotArea  OverallQual  OverallCond    YearBuilt  YearRemodAdd  \
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean    10516.828082     6.099315     5.575342  1971.267808   1984.865753
# std      9981.264932     1.382997     1.112799    30.202904     20.645407
# min      1300.000000     1.000000     1.000000  1872.000000   1950.000000
# 25%      7553.500000     5.000000     5.000000  1954.000000   1967.000000
# 50%      9478.500000     6.000000     5.000000  1973.000000   1994.000000
# 75%     11601.500000     7.000000     6.000000  2000.000000   2004.000000
# max    215245.000000    10.000000     9.000000  2010.000000   2010.000000
#
#        TotalBsmtSF     1stFlrSF     2ndFlrSF     FullBath  BedroomAbvGr  \
# count  1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean   1057.429452  1162.626712   346.992466     1.565068      2.866438
# std     438.705324   386.587738   436.528436     0.550916      0.815778
# ...

# %%
data2.columns
# Out:
# Index([u'LotArea', u'OverallQual', u'OverallCond', u'YearBuilt',
#        u'YearRemodAdd', u'TotalBsmtSF', u'1stFlrSF', u'2ndFlrSF', u'FullBath',
#        u'BedroomAbvGr', u'GarageFinish', u'GarageCars', u'OpenPorchSF',
#        u'PoolQC', u'MiscVal', u'YrSold', u'SalePrice', u'HouseStyle_1.5Fin',
#        u'HouseStyle_1.5Unf', u'HouseStyle_1Story', u'HouseStyle_2.5Fin',
#        u'HouseStyle_2.5Unf', u'HouseStyle_2Story', u'HouseStyle_SFoyer',
#        u'HouseStyle_SLvl'],
#       dtype='object')

# %%
import seaborn as sns
g=sns.pairplot(data2[[u'YearBuilt',
       u'TotalBsmtSF', u'SalePrice']], palette='Set2')

# %%
import seaborn as sns
g=sns.pairplot(data2[[u'LotArea', u'OverallQual', u'OverallCond', u'YearBuilt',
       u'TotalBsmtSF', u'1stFlrSF', u'2ndFlrSF', u'BedroomAbvGr',
       u'GarageCars', u'YrSold', u'SalePrice']], palette = 'seismic')
# g= sns.pairplot(data2[[u'LotArea', u'OverallQual', u'OverallCond', u'YearBuilt',
#         u'TotalBsmtSF', u'1stFlrSF', u'2ndFlrSF', u'BedroomAbvGr',
#         u'GarageCars', u'OpenPorchSF', u'PoolQC', u'YrSold', u'SalePrice']], palette = 'seismic')
# g = sns.pairplot(data2[[u'LotArea', u'OverallQual', u'OverallCond', u'YearBuilt',
#        u'TotalBsmtSF', u'1stFlrSF', u'2ndFlrSF', u'BedroomAbvGr',
#        u'GarageCars', u'OpenPorchSF', u'PoolQC', u'YrSold', u'SalePrice']], palette = 'seismic',size=1.2,diag_kind = 'kde',diag_kws=dict(shade=True),plot_kws=dict(s=10) )
# g.set(xticklabels=[])

# %%
###########################

# %%
# from sklearn.preprocessing import Imputer, StandardScaler
# from sklearn.pipeline import Pipeline

# from sklearn.neighbors import KNeighborsClassifier

# %%
# knn = KNeighborsClassifier()
# imp = Imputer()
# sc = StandardScaler()
# pipe = Pipeline([('scaler', sc), ('knn', knn)])

# %%
# params = {'knn__n_neighbors': list(range(3, 16, 2))}

# %%
# from sklearn.model_selection import GridSearchCV
# grid = GridSearchCV(pipe, params, cv=5)

# %%
# X_tr = imp.fit_transform(X_tr)
# X_ts = imp.transform(X_ts)
# grid.fit(X_tr, y_tr)

# %%
# from sklearn.metrics import accuracy_score
# preds = grid.predict(X_ts)
# accuracy_score(y_ts, preds)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import VarianceThreshold
from sklearn.decomposition import PCA

pipe = Pipeline(steps=[#('selector', VarianceThreshold()),
                       #('pca', PCA()),
                       ('random_forest',RandomForestRegressor())])

param_grid = {#'selector__threshold': [0.0, 0.005],
              #'pca__n_components': [15, 20],
              'random_forest__n_estimators':[25, 50, 80]}

grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
grid.best_estimator_
# Out:
# Pipeline(memory=None,
#      steps=[('random_forest', RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=80, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False))])

# %%
preds = grid.predict(X_test)

# %%
rmsle(y_test, preds)
# Out:
# 0.1318996095431521

# %%
X_train.shape
# Out:
# (1095, 24)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)

preds = lr.predict(X_test)
print('rmsle:', rmsle(y_test, preds).round(3))
# Out:
# ('rmsle:', 0.167)

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(max_depth=1)
reg.fit(X_train, y_train)
pred = reg.predict(X_test)
print(rmsle(y_test, pred).round(3))
# Out:
# 0.309

# %%
from sklearn import linear_model

clf = linear_model.Lasso(alpha=1)
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
print(rmsle(y_test, pred).round(3))
# Out:
# 0.167

# %%
from sklearn.neural_network import MLPRegressor
mlp = MLPRegressor()
mlp.fit(X_train, y_train)
pred = mlp.predict(X_test)
print(rmsle(y_test, pred).round(3))
# Out:
# 0.3
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
